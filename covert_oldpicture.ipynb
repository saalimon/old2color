# %% [markdown]
# <a href="https://colab.research.google.com/github/saalimon/old2color/blob/master/covert_oldpicture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %%
# !unzip -x habr_demo.zip

# %%
from sklearn.model_selection import train_test_split
SEED = 44000

# %%
import cv2

# %%
data = []
label = []

# %%
type(data)
# Out:
# list

# %%
data_in = os.listdir("./habr_demo/input")

# %%
label_in = os.listdir("./habr_demo/colorized")

# %%
df = pd.DataFrame({
    'data': data_in,
    'label': label_in
})

# %%
df.head()
# Out:
#                  data               label
# 0         7744551.jpg         7744551.jpg
# 1  color_test0121.jpg  color_test0121.jpg
# 2  color_test0137.jpg  color_test0137.jpg
# 3   0000002672_1.jpeg   0000002672_1.jpeg
# 4  color_test0087.jpg  color_test0087.jpg

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
sample = random.choice(data_in)
image = load_img("./habr_demo/input/"+sample)
plt.imshow(image)

# %%
sample = random.choice(label_in)
image = load_img("./habr_demo/colorized/"+sample)
plt.imshow(image)

# %%
FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)
